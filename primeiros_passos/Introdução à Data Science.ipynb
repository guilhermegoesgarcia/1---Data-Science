# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
notas = pd.read_csv('data/ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.columns = ['usuarioid','filmeid','nota','momento']
notas.head()
# Out:
#    usuarioid  filmeid  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
filmes = pd.read_csv('data/movies.csv')
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.columns =['filmesid','titulo','genero']
filmes.head()
# Out:
#    filmesid                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.query('filmeid==1').nota
# Out:
# 0        4.0
# 516      4.0
# 874      4.5
# 1434     2.5
# 1667     4.5
# 1772     3.5
# 2274     4.0
# 3219     3.5
# 4059     3.0
# 4879     5.0
# 4929     3.0
# 5031     3.0
# 5555     5.0
# 6315     5.0
# 6429     3.0
# 6477     4.0
# 6876     5.0
# 7112     3.0
# 7931     3.0
# 8035     5.0
# 9157     5.0
# 9428     4.0
# 9979     4.0
# 10360    2.5
# 11728    5.0
# 11808    4.5
# 12264    0.5
# 12412    4.0
# 12730    2.5
# 13402    4.0
#         ...
# 84327    3.0
# 84603    3.0
# 84780    4.0
# 85291    4.0
# 85984    5.0
# 86124    3.0
# 86582    4.0
# 87087    4.5
# 87791    3.5
# 88219    4.0
# 88522    4.0
# 88677    5.0
# 89243    4.0
# 89316    3.0
# 89904    5.0
# 90256    5.0
# 90517    4.0
# 91748    4.0
# 92159    4.0
# 92623    3.0
# 95101    2.5
# 95864    4.0
# 96100    4.0
# 97043    3.0
# 97143    4.0
# 97364    2.5
# 98479    4.0
# 98666    2.5
# 99497    3.0
# 99534    5.0
# Name: nota, Length: 215, dtype: float64

# %%
notas.query('filmeid==1').nota.mean()
# Out:
# 3.9209302325581397

# %%
médias_por_filme = notas.groupby('filmeid').mean()['nota']
médias_por_filme
# Out:
# filmeid
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
# 6         3.946078
# 7         3.185185
# 8         2.875000
# 9         3.125000
# 10        3.496212
# 11        3.671429
# 12        2.421053
# 13        3.125000
# 14        3.833333
# 15        3.000000
# 16        3.926829
# 17        3.776119
# 18        3.700000
# 19        2.727273
# 20        2.500000
# 21        3.494382
# 22        3.222222
# 23        3.125000
# 24        3.125000
# 25        3.625000
# 26        3.500000
# 27        3.333333
# 28        4.227273
# 29        4.013158
# 30        3.000000
#             ...
# 188189    4.500000
# 188301    3.666667
# 188675    3.500000
# 188751    4.500000
# 188797    4.000000
# 188833    4.500000
# 189043    2.500000
# 189111    3.000000
# 189333    3.750000
# 189381    2.500000
# 189547    1.000000
# 189713    2.500000
# 190183    3.500000
# 190207    1.500000
# 190209    4.000000
# 190213    1.000000
# ...

# %%
sns.boxplot(y=médias_por_filme)

# %%
sns.boxplot(médias_por_filme)

# %%
filmes.head(5)
# Out:
#    filmesid                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.set_index('filmesid',inplace=True)

# %%
filmes
# Out:
#                                                      titulo  \
# filmesid
# 1                                          Toy Story (1995)
# 2                                            Jumanji (1995)
# 3                                   Grumpier Old Men (1995)
# 4                                  Waiting to Exhale (1995)
# 5                        Father of the Bride Part II (1995)
# 6                                               Heat (1995)
# 7                                            Sabrina (1995)
# 8                                       Tom and Huck (1995)
# 9                                       Sudden Death (1995)
# 10                                         GoldenEye (1995)
# 11                           American President, The (1995)
# 12                       Dracula: Dead and Loving It (1995)
# 13                                             Balto (1995)
# 14                                             Nixon (1995)
# ...

# %%
filmes.loc[[2],['titulo']]
# Out:
#                   titulo
# filmesid
# 2         Jumanji (1995)

# %% [markdown]
# ### Identificando as médias com os filmes pelos INDEX - ID

# %%
dic_medias = dict(médias_por_filme)

# %%
dic_medias
# Out:
# {1: 3.9209302325581397,
#  2: 3.4318181818181817,
#  3: 3.2596153846153846,
#  4: 2.357142857142857,
#  5: 3.0714285714285716,
#  6: 3.946078431372549,
#  7: 3.185185185185185,
#  8: 2.875,
#  9: 3.125,
#  10: 3.496212121212121,
#  11: 3.6714285714285713,
#  12: 2.4210526315789473,
#  13: 3.125,
#  14: 3.8333333333333335,
#  15: 3.0,
#  16: 3.926829268292683,
#  17: 3.7761194029850746,
#  18: 3.7,
#  19: 2.727272727272727,
#  20: 2.5,
#  21: 3.49438202247191,
#  22: 3.2222222222222223,
#  23: 3.125,
#  24: 3.125,
#  25: 3.625,
#  26: 3.5,
#  27: 3.3333333333333335,
#  28: 4.2272727272727275,
#  29: 4.0131578947368425,
#  30: 3.0,
#  31: 3.1842105263157894,
#  32: 3.983050847457627,
#  34: 3.65234375,
#  36: 3.8358208955223883,
#  38: 2.125,
#  39: 3.293269230769231,
#  40: 4.25,
#  41: 3.7,
#  42: 3.0,
#  43: 3.1875,
#  44: 2.5434782608695654,
#  45: 3.3125,
#  46: 3.066666666666667,
#  47: 3.9753694581280787,
#  48: 3.1470588235294117,
#  49: 3.0,
#  50: 4.237745098039215,
# ...

# %%
filmes.rename(index=dic_medias,inplace=True)
filmes
# Out:
#                                                      titulo  \
# filmesid
# 3.920930                                   Toy Story (1995)
# 3.431818                                     Jumanji (1995)
# 3.259615                            Grumpier Old Men (1995)
# 2.357143                           Waiting to Exhale (1995)
# 3.071429                 Father of the Bride Part II (1995)
# 3.946078                                        Heat (1995)
# 3.185185                                     Sabrina (1995)
# 2.875000                                Tom and Huck (1995)
# 3.125000                                Sudden Death (1995)
# 3.496212                                   GoldenEye (1995)
# 3.671429                     American President, The (1995)
# 2.421053                 Dracula: Dead and Loving It (1995)
# 3.125000                                       Balto (1995)
# 3.833333                                       Nixon (1995)
# ...

# %% [markdown]
# ### Renomeando o Index

# %%
filmes.rename_axis('médias',axis=1,inplace=True)
filmes
# Out:
# médias                                               titulo  \
# filmesid
# 3.920930                                   Toy Story (1995)
# 3.431818                                     Jumanji (1995)
# 3.259615                            Grumpier Old Men (1995)
# 2.357143                           Waiting to Exhale (1995)
# 3.071429                 Father of the Bride Part II (1995)
# 3.946078                                        Heat (1995)
# 3.185185                                     Sabrina (1995)
# 2.875000                                Tom and Huck (1995)
# 3.125000                                Sudden Death (1995)
# 3.496212                                   GoldenEye (1995)
# 3.671429                     American President, The (1995)
# 2.421053                 Dracula: Dead and Loving It (1995)
# 3.125000                                       Balto (1995)
# 3.833333                                       Nixon (1995)
# ...

# %%
filmes.rename_axis('',axis=0,inplace=True)
filmes
# Out:
# médias                                               titulo  \
#
# 3.920930                                   Toy Story (1995)
# 3.431818                                     Jumanji (1995)
# 3.259615                            Grumpier Old Men (1995)
# 2.357143                           Waiting to Exhale (1995)
# 3.071429                 Father of the Bride Part II (1995)
# 3.946078                                        Heat (1995)
# 3.185185                                     Sabrina (1995)
# 2.875000                                Tom and Huck (1995)
# 3.125000                                Sudden Death (1995)
# 3.496212                                   GoldenEye (1995)
# 3.671429                     American President, The (1995)
# 2.421053                 Dracula: Dead and Loving It (1995)
# 3.125000                                       Balto (1995)
# 3.833333                                       Nixon (1995)
# 3.000000                            Cutthroat Island (1995)
# ...

# %%
filmes.head()
# Out:
# médias                                titulo  \
#
# 3.920930                    Toy Story (1995)
# 3.431818                      Jumanji (1995)
# 3.259615             Grumpier Old Men (1995)
# 2.357143            Waiting to Exhale (1995)
# 3.071429  Father of the Bride Part II (1995)
#
# médias                                         genero
#
# 3.920930  Adventure|Animation|Children|Comedy|Fantasy
# 3.431818                   Adventure|Children|Fantasy
# 3.259615                               Comedy|Romance
# 2.357143                         Comedy|Drama|Romance
# 3.071429                                       Comedy
