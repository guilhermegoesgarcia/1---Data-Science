# %% [markdown]
# # Aula 1

# %% [markdown]
# ## Vídeo 1.2

# %%
import pandas as pd

# %%
carbonico = pd.read_csv('co2.csv',sep='\t')

# %%
carbonico.head()
# Out:
#        data   media
# 0  1980.042  338.45
# 1  1980.125  339.15
# 2  1980.208  339.48
# 3  1980.292  339.87
# 4  1980.375  340.30

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(carbonico['data'],carbonico['media'])
plt.ylabel('CO2')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
nasc = pd.read_csv('nascimentos.csv')

# %%
nasc.head()
# Out:
#          data  n_nasc
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
plt.plot(nasc["data"],nasc['n_nasc'])
plt.ylabel("Número de nascimentos")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
nasc["data"] = pd.to_datetime(nasc["data"])

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
plt.figure(figsize = (8,4));
plt.plot(nasc["data"],nasc['n_nasc'])
plt.ylabel("Número de nascimentos")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ## Vídeo 1.3

# %%
import numpy as np

# %%
media_carb = np.mean(carbonico["media"])

# %%
dt_carb = carbonico["data"][1]-carbonico["data"][0]

# %%
plt.plot(carbonico["data"],carbonico['media'])
plt.plot(carbonico.iloc[-1,0]+dt_carb,media_carb, '*')
plt.ylabel("CO2")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
media_nasc = np.mean(nasc["n_nasc"])

# %%
dt_nasc = nasc["data"][1]-nasc["data"][0]

# %%
plt.plot(nasc["data"],nasc["n_nasc"])
plt.plot(nasc.iloc[-1,0]+dt_nasc,media_nasc, '*')
plt.ylabel("Número de nascimentos")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
carbonico.shape
# Out:
# (477, 2)

# %%
media_tres_pontos_c = np.mean(carbonico["media"][474:476])

# %%
plt.plot(carbonico["data"],carbonico['media'])
plt.plot(carbonico.iloc[-1,0]+dt_carb,media_tres_pontos_c, '*')
plt.ylabel("CO2")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
nasc.shape
# Out:
# (365, 2)

# %%
media_tres_pontos_n = np.mean(nasc["n_nasc"][362:364])

# %%
plt.plot(nasc["data"],nasc["n_nasc"])
plt.plot(nasc.iloc[-1,0]+dt_nasc,media_tres_pontos_n, '*')
plt.ylabel("Número de nascimentos")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ## Reduzido o Ruido no gráfico para conseguirmos entender a tendencia:

# %%
media_movel_c = carbonico.rolling(50).mean()

# %%
media_movel_c
# Out:
#            data     media
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10          NaN       NaN
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14          NaN       NaN
# 15          NaN       NaN
# 16          NaN       NaN
# 17          NaN       NaN
# 18          NaN       NaN
# 19          NaN       NaN
# 20          NaN       NaN
# 21          NaN       NaN
# 22          NaN       NaN
# 23          NaN       NaN
# 24          NaN       NaN
# 25          NaN       NaN
# 26          NaN       NaN
# 27          NaN       NaN
# 28          NaN       NaN
# 29          NaN       NaN
# ..          ...       ...
# 447  2015.25000  399.3578
# 448  2015.33334  399.5646
# 449  2015.41666  399.7466
# ...

# %%
co2 =carbonico
co2.head()
# Out:
#        data   media
# 0  1980.042  338.45
# 1  1980.125  339.15
# 2  1980.208  339.48
# 3  1980.292  339.87
# 4  1980.375  340.30

# %%
plt.plot(co2['data'],co2['media'])
plt.plot(media_movel_c['data'],media_movel_c['media'])

# %%
nasc
# Out:
#           data  n_nasc
# 0   1959-01-01      35
# 1   1959-01-02      32
# 2   1959-01-03      30
# 3   1959-01-04      31
# 4   1959-01-05      44
# 5   1959-01-06      29
# 6   1959-01-07      45
# 7   1959-01-08      43
# 8   1959-01-09      38
# 9   1959-01-10      27
# 10  1959-01-11      38
# 11  1959-01-12      33
# 12  1959-01-13      55
# 13  1959-01-14      47
# 14  1959-01-15      45
# 15  1959-01-16      37
# 16  1959-01-17      50
# 17  1959-01-18      43
# 18  1959-01-19      41
# 19  1959-01-20      52
# 20  1959-01-21      34
# 21  1959-01-22      53
# 22  1959-01-23      39
# 23  1959-01-24      32
# 24  1959-01-25      37
# 25  1959-01-26      43
# 26  1959-01-27      39
# 27  1959-01-28      35
# 28  1959-01-29      44
# 29  1959-01-30      38
# ..         ...     ...
# 335 1959-12-02      32
# 336 1959-12-03      46
# 337 1959-12-04      41
# 338 1959-12-05      34
# 339 1959-12-06      33
# 340 1959-12-07      36
# 341 1959-12-08      49
# 342 1959-12-09      43
# ...

# %%
media_movel_n =pd.DataFrame( nasc['n_nasc'].rolling(5).mean() )

# %%
plt.plot( nasc['data'],nasc['n_nasc'])
plt.plot( nasc['data'], media_movel_n['n_nasc'])

# %% [markdown]
# ## Fazendo a decomposição da serie temporal

# %%
#!pip install statsmodels==v0.11.0rc2

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result_c = seasonal_decompose(co2.set_index('data'),period=35)

# %%
result_c.plot()

# %%
result_n = seasonal_decompose(nasc.set_index('data'),period=35)

# %%
result_n.plot()

# %% [markdown]
# ### Verificando se a serie é estacionaria

# %%
co2['media'].hist()

# %% [markdown]
# #### Obs.. não estamos observando uma serie estacionaria, pois o gáfico de histograma não se parece com um sino..

# %%
divide = int(len(co2)/2)

# %%
x = co2['media'].values

# %%
c1,c2 = x[0:divide],x[divide:]

# %%
c1.mean()
# Out:
# 352.31550420168065

# %%
c2.mean()
# Out:
# 387.816359832636

# %% [markdown]
# ### obs. para ser estacionario as médias devem ter o valores próximos da média e variancia.. portanto é mais um indicativo que a série não e estácionaria

# %%
c1.var()
# Out:
# 73.90219533401597

# %%
c2.var()
# Out:
# 151.542490933282

# %% [markdown]
# ## Vamos verificar os valores do DataFrame Nasc.

# %%
divide = int(len(nasc)/2)

# %%
x = nasc['n_nasc'].values

# %%
n1,n2 = x[0:divide] ,x[divide:]

# %%
print(f'''
        --Médias--
N1_Média : {n1.mean()}
N2_Média : {n2.mean()}

        --Variancia--
        
N1_Var : {n1.var()}
N2_Var : {n2.var()} ''')
# Out:
#         --Médias--
# N1_Média : 39.76373626373626
# N2_Média : 44.185792349726775
#
#         --Variancia--
#
# N1_Var : 49.21341021615746
# N2_Var : 48.708650601690096

# %%
nasc.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019A989571D0>]],
#       dtype=object)

# %% [markdown]
# ## Teste ADF:

# %%
from statsmodels.tsa.stattools import adfuller

# %%
resultado_c = adfuller(co2['media'].values)

# %%
print(' Estátistica ADF  série CO2:', resultado_c[0])
# Out:
#  Estátistica ADF  série CO2: 3.036828829166984

# %% [markdown]
# ### Quanto mais negativo for o resultado do ADF mais estacionária é a série.

# %%
print(' p-valor:', resultado_c[1])
# Out:
#  p-valor: 1.0

# %% [markdown]
# ### Quando o 'p-valor' for menor que 0.05 --> a serie é estacionario
# ### Maior que 0.05 --> Não é estacionária

# %%
resultado_n = adfuller(nasc['n_nasc'].values)

# %%
print(' Estátistica ADF  série Nascimento:', resultado_n[0])
# Out:
#  Estátistica ADF  série Nascimento: -4.808291253559764

# %%
print(' p-valor:', resultado_n[1])
# Out:
#  p-valor: 5.2434129901498554e-05

# %% [markdown]
# #### Conseguimos demonstrar mais um indicativo que a série Nascimento é estácionaria

# %% [markdown]
# # _ Previsão de Valores Futuros_

# %%
co2 = co2.set_index('data')

# %%
co2_treino = co2[1980.042:2015]

# %%
co2_teste = co2[2015:]

# %% [markdown]
# ## Suavisando os dados e depois aplicando uma previsão no ajuste feito:

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
modelo_ajustado = SimpleExpSmoothing(co2_treino).fit(smoothing_level=0.5)
# Out:
# C:\Users\Guilherme\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Guilherme\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:726: RuntimeWarning: invalid value encountered in greater
#   loc = p[xi] > ub

# %%
co2_teste.shape
# Out:
# (57, 1)

# %%
modelo_previsto = modelo_ajustado.forecast(57)
# Out:
# C:\Users\Guilherme\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
plt.plot(co2_treino)
plt.plot(co2_treino.index,modelo_ajustado.fittedvalues.values)
plt.plot(co2_teste,'g')
plt.plot(co2_teste.index,modelo_previsto,'r')

# %%
nasc = nasc.set_index('data')

# %%
nasc_treino = nasc['1959-01-01':'1959-12-01']

# %%
nasc_teste = nasc['1959-12-01':]

# %%
modelo_ajustado = SimpleExpSmoothing(nasc_traino).fit(smoothing_level=0.5)
# Out:
# C:\Users\Guilherme\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\Guilherme\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:726: RuntimeWarning: invalid value encountered in greater
#   loc = p[xi] > ub

# %%
nasc_teste.shape[0]
# Out:
# 31

# %%
modelo_previsto  = modelo_ajustado.forecast(31)

# %%
plt.plot(nasc_treino)
plt.plot(nasc_treino.index,modelo_ajustado.fittedvalues.values)
plt.plot(nasc_teste,'g')
plt.plot(nasc_teste.index,modelo_previsto,'r.')

# %% [markdown]
# # _Método de HoltWinter_

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
modelo_ajustado =  ExponentialSmoothing(co2_treino.values,trend='additive',seasonal='additive',seasonal_periods=35).fit()
# Out:
# C:\Users\Guilherme\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:723: RuntimeWarning: invalid value encountered in less
#   loc = p[xi] < lb
# C:\Users\Guilherme\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:735: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
co2.shape
# Out:
# (477, 1)

# %%
co2_teste.shape
# Out:
# (57, 1)

# %%
modelo_previsto = modelo_ajustado.predict(start=420,end=476)

# %%
plt.figure(figsize=(8,4))
plt.plot(co2_treino)
plt.plot(co2_teste,'g')
plt.plot(co2_teste.index, modelo_previsto,'r.')

# %%
modelo_ajustado = ExponentialSmoothing(nasc_treino.values,trend='multiplicative', seasonal =None).fit()

# %%
nasc_treino.shape
# Out:
# (335, 1)

# %%
nasc_teste.shape
# Out:
# (31, 1)

# %%
modelo_previsto_suave = modelo_ajustado.predict(start=335, end=365)

# %%
plt.figure(figsize=(8,4))
plt.plot(nasc_treino)
plt.plot(nasc_teste,'g')
plt.plot(nasc_teste.index, modelo_previsto_suave,'r.')

# %% [markdown]
# # _ Modelo de autorregressão_

# %% [markdown]
# ### Verifica a periodicidade e sacionalidade dos dados .. aparentando quando va = vb

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(co2); # colocar ';' para se gerar apenas 1 grafico

# %% [markdown]
# #### pontos acima do cone azul significa que existe correlaçoes  efetivas , já abaixo, correlações de ruidos

# %% [markdown]
# ### auto correlação parcial...

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(co2, lags=20);

# %%
plot_pacf(nasc, lags=20);

# %% [markdown]
# ### AutoRegreção

# %%
from statsmodels.tsa.ar_model import AutoReg

# %%
lista = np.linspace(1,40,40)

# %%
modelo_ajustado = AutoReg(co2_treino.values,lags=lista,trend='c',seasonal=True, period=35).fit()

# %%
modelo_previsto = modelo_ajustado.predict(start=420, end=476)

# %%
plt.plot(co2_treino)
plt.plot(co2_teste,'g')
plt.plot(co2_teste.index,modelo_previsto,'r.')

# %%
modelo_ajustado = AutoReg(nasc_treino.values,lags=lista,trend='c',seasonal=True, period=35).fit()

# %%
modelo_previsto_ar = modelo_ajustado.predict(start=335, end=365)

# %%
plt.plot(nasc_treino)
plt.plot(nasc_teste,'g')
plt.plot(nasc_teste.index,modelo_previsto_ar,'r.')

# %% [markdown]
# # Verificando Qual método de previsão melhor se adaptou ao nosso modelo..

# %%
plt.plot(nasc_teste,'g',label='valor_real')
plt.plot(nasc_teste.index, modelo_previsto_suave,'b-',label='previsão HoltWinters')
plt.plot(nasc_teste.index,modelo_previsto_ar,'r',label='previsão autorregressão')

# %%
Erro_prev_s = nasc_teste['n_nasc'] - modelo_previsto_suave

# %%
Erro_prev = nasc_teste['n_nasc'] - modelo_previsto_ar

# %%
plt.plot(Erro_prev_s,'g',label='Erro Suave')
plt.plot(Erro_prev,'r',label='Erro Ar')

# %%
np.mean(Erro_prev_s)
# Out:
# -3.5361230284103122

# %%
np.mean(Erro_prev)
# Out:
# -1.6083080804501086

# %% [markdown]
# #### Quanto mais próximo de zero melhor

# %%
np.mean(np.abs(Erro_prev_s))
# Out:
# 6.374536496080955

# %%
np.mean(np.abs(Erro_prev))
# Out:
# 5.496720548092111

# %% [markdown]
# ## Calculo de erros de forma rápida

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(nasc_teste['n_nasc'],modelo_previsto_ar)

# %%
mae
# Out:
# 5.496720548092111

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(nasc_teste['n_nasc'], modelo_previsto_suave)
# Out:
# 54.39584423712526

# %%
mean_squared_error(nasc_teste['n_nasc'],modelo_previsto_ar)
# Out:
# 45.43739422181352
